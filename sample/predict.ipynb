# %%
import os
import glob
import sys
import subprocess
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

SAMPLE_IMG = './vlcsnap-2022-08-17-23h05m09s384.png'
CALIB_JSON = './sample.json'

# %%
plt.imshow(plt.imread(SAMPLE_IMG))

# %%
command = "python ./demo/mono_det_demo.py %s %s configs/fcos3d/fcos3d_r101_caffe_fpn_gn-head_dcn_2x8_1x_nus-mono3d_finetune.py checkpoints/fcos3d_r101_caffe_fpn_gn-head_dcn_2x8_1x_nus-mono3d_finetune_20210717_095645-8d806dc2.pth" % (os.path.abspath(SAMPLE_IMG), os.path.abspath(CALIB_JSON))
proc = subprocess.Popen(command.split(), cwd='/workspace')
# Out:
# Traceback (most recent call last):
#   File "./demo/mono_det_demo.py", line 4, in <module>
#     from mmdet3d.apis import (inference_mono_3d_detector, init_model,
#   File "/mmdetection3d/mmdet3d/__init__.py", line 5, in <module>
#     import mmseg
#   File "/opt/conda/lib/python3.7/site-packages/mmseg/__init__.py", line 59, in <module>
#     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
# AssertionError: MMCV==1.6.0 is used but incompatible. Please install mmcv>=(1, 3, 13, 0, 0, 0), <=(1, 5, 0, 0, 0, 0).

# %%
# !pip install mmdet3d

# %%
import mmdet3d
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_12/1831087849.py in <module>
# ----> 1 import mmdet3d
#
# /mmdetection3d/mmdet3d/__init__.py in <module>
#       3
#       4 import mmdet
# ----> 5 import mmseg
#       6 from .version import __version__, short_version
#       7
#
# /opt/conda/lib/python3.7/site-packages/mmseg/__init__.py in <module>
#      57
#      58 assert (mmcv_min_version <= mmcv_version <= mmcv_max_version), \
# ---> 59     f'MMCV=={mmcv.__version__} is used but incompatible. ' \
#      60     f'Please install mmcv>={mmcv_min_version}, <={mmcv_max_version}.'
#      61
#
# AssertionError: MMCV==1.6.0 is used but incompatible. Please install mmcv>=(1, 3, 13, 0, 0, 0), <=(1, 5, 0, 0, 0, 0).
